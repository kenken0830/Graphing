# %% [markdown]
# <a href="https://colab.research.google.com/github/kenken0830/Graphing/blob/main/informative_drawings2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![000.jpg](data:image/jpeg;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/AI/informative-drawings
# Out:
# /content/drive/MyDrive/AI/informative-drawings

# %%
#@title **1.セットアップ**

# widget_manager version_down
# !pip install "ipywidgets>=7,<8"
from google.colab import output
output.enable_custom_widget_manager()

# githubからコードを取得
#! git clone https://github.com/sugi-san/informative-drawings.git
#%cd informative-drawings

# checkpointsフォルダ作成
#import os
#os.makedirs('checkpoints', exist_ok=True)

# 学習済みパラメータのダウンロード
! pip install --upgrade gdown
import gdown

#for i in range(10):
#  if os.path.isfile('model.zip'): 
#    break
#  else:
#    gdown.download('https://drive.google.com/uc?id=11l5u5sb1PO5Z5YA3IoEHauVPm0k407C1', 'model.zip', quiet=False)
#! unzip model.zip -d checkpoints

# 関数読み込み
from function import *

# downloadフォルダ作成
import os
os.makedirs('movie/download', exist_ok=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 9.6 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...

# %% [markdown]
# ![003.jpg](data:image/jpeg;base64,...)

# %%
#@title **2.写真の表示**
display_pic('examples/test')

# %%
#@title **3.写真のスケッチ変換**
! python test.py --name model/contour_style --dataroot examples/test --size 512
display_pic('results/model/contour_style')
# Out:
# Namespace(aspect_ratio=1.0, batchSize=1, checkpoints_dir='checkpoints', crop_size=256, cuda=True, dataroot='examples/test', depthroot='', every_feat=1, geom_name='feats2Geom', geom_nc=3, how_many=100, input_nc=3, load_size=256, max_dataset_size=inf, midas=0, mode='test', n_blocks=3, n_cpu=8, name='model/contour_style', ngf=64, no_flip=False, norm='instance', num_classes=55, output_nc=1, predict_depth=0, preprocess='resize_and_crop', reconstruct=0, results_dir='results', save_input=0, size=512, which_epoch='latest')
# loaded checkpoints/model/contour_style/netG_A_latest.pth
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# Generated images 0002 of 0100

# %%
#@title **3.写真のスケッチ変換**
! python test.py --name model/opensketch_style --dataroot examples/test --size 512
display_pic('results/model/opensketch_style')

# %%
#@title **3.写真のスケッチ変換**
! python test.py --name model/opensketch_style --dataroot examples/test --size 512
display_pic('results/model/opensketch_style')
# Out:
# Namespace(aspect_ratio=1.0, batchSize=1, checkpoints_dir='checkpoints', crop_size=256, cuda=True, dataroot='examples/test', depthroot='', every_feat=1, geom_name='feats2Geom', geom_nc=3, how_many=100, input_nc=3, load_size=256, max_dataset_size=inf, midas=0, mode='test', n_blocks=3, n_cpu=8, name='model/opensketch_style', ngf=64, no_flip=False, norm='instance', num_classes=55, output_nc=1, predict_depth=0, preprocess='resize_and_crop', reconstruct=0, results_dir='results', save_input=0, size=512, which_epoch='latest')
# loaded checkpoints/model/opensketch_style/netG_A_latest.pth
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# Generated images 0002 of 0100

# %%
#@title **4.画像のダウンロード**
#@markdown　・zip形式でまとめてダウンロードします
! zip -r data results/model/opensketch_style

from google.colab import files
files.download('data.zip')

# %% [markdown]
# ![002.jpg](data:image/jpeg;base64,...)

# %%
#@title **5.ビデオの表示**
import os
import glob
print('=== video ===')
reset_folder('movie/pic_video')
files = sorted(glob.glob('movie/video/*.mp4'))
names = []
for file in files:
  name = os.path.basename(file)
  save_frame(name, 'movie/video', 'movie/pic_video')
  names.append(name)
display_movie('movie/pic_video', names)
# Out:
# === video ===
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12491 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#@title **6.ビデオのスケッチ変換**

# --- ビデオを静止画にバラす ---
video = 'TV\u30A2\u30CB\u30E1\u300C\u30EF\u30F3\u30D2\u309A\u30FC\u30B9\u300D15\u5468\u5E74\u8A18\u5FF5\uFF0115\u306E\u540D\u5834\u9762\u3066\u3099\u7DB4\u308B\u611F\u6D99PV-3VdqvSKFzE8.mp4' #@param {type:"string"}
video_file = 'movie/video/'+video
style = 'model/anime_style' 
size = 1024

import os
import shutil
import cv2

# 出力フォルダーリセット
reset_folder('movie/images')
 
def video_2_images(video_file= video_file,   # ビデオの指定
                   image_dir='movie/images/', 
                   image_file='%s.jpg'):  

    # Initial setting
    i = 0
    interval = 1
    length = 300000  # 最大フレーム数
    
    cap = cv2.VideoCapture(video_file)
    fps = cap.get(cv2.CAP_PROP_FPS)  # fps取得

    while(cap.isOpened()):
        flag, frame = cap.read()  
        if flag == False:  
                break
        if i == length*interval:
                break
        if i % interval == 0:    
           cv2.imwrite(image_dir+image_file % str(int(i/interval)).zfill(6), frame)
        i += 1 
    cap.release()
    return fps, i, interval
 
fps, i, interval = video_2_images()

print('fps = ', fps)
print('frames = ', i)
print('interval = ', interval)


# --- 静止画をスケッチに変換 ---
# 出力フォルダーリセット
reset_folder('movie/sketch/'+style)

# スケッチ変換
! python test.py --name $style\
                 --dataroot movie/images\
                 --results_dir movie/sketch\
                 --how_many 300000\
                 --size $size


# --- 動画の作成 ---
# 動画の作成
print('makeing movie...')
file_path = 'movie/sketch/'+style+'/%06d_out.png'
! ffmpeg -y -r $fps -i $file_path -vcodec libx264 -pix_fmt yuv420p -loglevel error out.mp4

# 音声の抽出・付加
print('preparation for sound...')
! ffmpeg -y -i $video_file -loglevel error sound.mp3
! ffmpeg -y -i out.mp4 -i sound.mp3 -loglevel error output.mp4

# 動画の再生
print('waiting for play movie...')
display_mp4('output.mp4')
# Out:
# fps =  29.97002997002997
# frames =  48401
# interval =  1
# Namespace(aspect_ratio=1.0, batchSize=1, checkpoints_dir='checkpoints', crop_size=256, cuda=True, dataroot='movie/images', depthroot='', every_feat=1, geom_name='feats2Geom', geom_nc=3, how_many=300000, input_nc=3, load_size=256, max_dataset_size=inf, midas=0, mode='test', n_blocks=3, n_cpu=8, name='model/anime_style', ngf=64, no_flip=False, norm='instance', num_classes=55, output_nc=1, predict_depth=0, preprocess='resize_and_crop', reconstruct=0, results_dir='movie/sketch', save_input=0, size=1024, which_epoch='latest')
# loaded checkpoints/model/anime_style/netG_A_latest.pth
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# ...

# %%
#@title **7.動画のダウンロード**

import os
import shutil

download_name = 'movie/download/'+os.path.splitext(video)[0]+'_sketch.mp4'
shutil.copy('output.mp4', download_name)

from google.colab import files
files.download(download_name)

# %% [markdown]
# ![001.jpg](data:image/jpeg;base64,...)

# %%
#@title **8.データのアップロード**
#@markdown ・selectでpicture（.jpg）かvideo（.mp4）を選択して下さい\
#@markdown ・動画はHD以下、20秒以内を目安にして下さい
import os
import shutil
from google.colab import files
import cv2

select = 'video' #@param ["picture", "video"]

# ルートへ画像をアップロード
uploaded = files.upload()           
uploaded = list(uploaded.keys())    

# ルートから指定フォルダーへ移動
if select == 'picture':
  for file in uploaded:
      if os.path.splitext(file)[1] != '.jpg':
        break
      shutil.move(file, 'examples/test/'+file)
      
if select == 'video':
  for file in uploaded:
      if os.path.splitext(file)[1] != '.mp4':
        break
      shutil.move(file, 'movie/video/'+file)
# Out:
#      <input type="file" id="files-e699178f-6e10-4673-bc35-735eca1cc868" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e699178f-6e10-4673-bc35-735eca1cc868">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###【備考】
# ・ブラウザは、必ずGoogle Chromeを使用して下さい。
#
# ・動作がおかしくなった場合の対応\
# １）グーグルクロームの該当タブを削除して接続を切る\
# ２）再度リンクを開く\
# ３）右上にある「ランタイム／ランタイムを出荷時設定にリセット」をクリックする（下記写真を参照に下さい）\
# ４）あとは、動画にある通りの操作をすればOK

# %% [markdown]
# ![説明図.jpg](data:image/jpeg;base64,...)
